# %%
import pandas as pd

# %%
data = pd.read_csv('./TephraDataBase_renormalizado_sample_distance_to_all_sample_RMSE_to_regression.csv')
# Out:
# <ipython-input-2-d8777225ef60>:1: DtypeWarning: Columns (7,14,20,21,29,30,31,44,49,53,59,76,77,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('./TephraDataBase_renormalizado_sample_distance_to_all_sample_RMSE_to_regression.csv')

# %%
list(data.columns)
# Out:
# ['ID',
#  'Volcano',
#  'Location',
#  'Event',
#  'Vei',
#  'Magnitude',
#  'Comments',
#  'ISGN',
#  'Flag',
#  'FlagDescription',
#  'TypeOfAnalysis',
#  'Latitude',
#  'Longitude',
#  'DOI',
#  'Map?',
#  'TypeOfRegister',
#  'MeasuredMaterial',
#  'TypeOfSection',
#  'SectionID',
#  'SubSectionID',
#  'SubSection_DistanceFromTop',
#  'HistoricalAge',
#  'RadiocarbonLabCode',
#  '14C_Age',
#  '14C_Age_Error',
#  'StratigraphicPosition',
#  '40Ar39Ar_Age',
#  '40Ar39Ar_Age_Error',
#  'DepositColor',
#  'DepositThickness_cm',
#  'GrainSize_min_mm',
#  'GrainSize_max_mm',
#  'MeasurementRun',
#  'Authors',
#  'AnalyticalTechnique',
#  'SampleID',
#  'SampleObservationID',
#  'SiO2',
#  'TiO2',
#  'Al2O3',
#  'FeO',
#  'Fe2O3',
#  'Fe2O3T',
#  'FeOT',
#  'MnO',
#  'MgO',
#  'CaO',
#  'Na2O',
#  'K2O',
#  'P2O5',
#  'Cl',
#  'LOI',
#  'Total',
#  'Rb',
#  'Sr',
#  'Y',
#  'Zr',
#  'Nb',
#  'Cs',
#  'Ba',
#  'La',
#  'Ce',
#  'Pr',
#  'Nd',
#  'Sm',
#  'Eu',
#  'Gd',
#  'Tb',
#  'Dy',
# ...

# %%
 columns_to_keep = ['ID', 
'Volcano',
'Event',
'Flag',
'SampleID',
 'SampleObservationID',
 'SiO2',
 'TiO2',
 'Al2O3',
 'FeO',
 'Fe2O3',
 'Fe2O3T',
 'FeOT',
 'MnO',
 'MgO',
 'CaO',
 'Na2O',
 'K2O',
 'P2O5',
 'Cl',
 'LOI',
 'Total',
 'Rb',
 'Sr',
 'Y',
 'Zr',
 'Nb',
 'Cs',
 'Ba',
 'La',
 'Ce',
 'Pr',
 'Nd',
 'Sm',
 'Eu',
 'Gd',
 'Tb',
 'Dy',
 'Ho',
 'Er',
 'Tm',
 'Yb',
 'Lu',
 'Hf',
 'Ta',
 'Pb',
 'Th',
 'U',
 '87Sr_86Sr',
 '2SE_87Sr_86Sr',
 '143Nd_144Nd',
 '2SE_143Nd_144Nd']

# %%
new_data = data.loc[:, columns_to_keep]

# %%
new_data.to_csv('./TephraDataBase_renormalizado_scatterplot.csv')
